# %%
import os
import torch
import numpy as np
from kan import *

# %%
def process_torchdataset(dataset, number):
  imgs, labels = zip(*dataset)
  X = torch.cat(imgs, axis=0).flatten(1)
  Y = torch.from_numpy(np.vstack(labels)[:, 1:3]) if number==1 else torch.from_numpy(np.vstack(labels)[:, -2:])
  return X, Y.long()

def create_dataset_from_files(data_dir, data_filenames, max_n=1000):
    dataset = {}
    for name in ["train", "test"]:
      X, Y = [], []
      for filename, number in zip(data_filenames,  [1,9]):
          data = torch.load(os.path.join(data_dir, "{}_{}".format(name, filename)))[:max_n]
          x, y = process_torchdataset(data, number)
          X.extend(x)
          Y.extend(y)
      dataset[f'{name}_input'] = torch.stack(X, axis=0)
      dataset[f'{name}_label'] = torch.stack(Y, axis=0)
    return dataset

# %%
data_dir = "/home/carolina/Anansi/MA/KG/MNIST/data/MNIST/excluded_1_9"
data_filenames = ["GAP_1_normalized.pt", "GAP_9_normalized.pt"]
dataset = create_dataset_from_files(data_dir, data_filenames, max_n=50)

# %%
model = KAN(width=[784, 128, 64, 32, 16, 2], grid=10, k=3, seed=0, symbolic_enabled=True,
            bias_trainable=False, sp_trainable=False, sb_trainable=False)
model
# Out:
# KAN(
#   (biases): ModuleList(
#     (0): Linear(in_features=128, out_features=1, bias=False)
#     (1): Linear(in_features=64, out_features=1, bias=False)
#     (2): Linear(in_features=32, out_features=1, bias=False)
#     (3): Linear(in_features=16, out_features=1, bias=False)
#     (4): Linear(in_features=2, out_features=1, bias=False)
#   )
#   (act_fun): ModuleList(
#     (0-4): 5 x KANLayer(
#       (base_fun): SiLU()
#     )
#   )
#   (base_fun): SiLU()
#   (symbolic_fun): ModuleList(
#     (0-4): 5 x Symbolic_KANLayer()
#   )
# )

# %%
total_params = 0
for name, param in model.named_parameters():
    print(name, param.shape)
    total_params += param.flatten().shape[0]
print(total_params)
# Out:
# biases.0.weight torch.Size([1, 128])
# biases.1.weight torch.Size([1, 64])
# biases.2.weight torch.Size([1, 32])
# biases.3.weight torch.Size([1, 16])
# biases.4.weight torch.Size([1, 2])
# act_fun.0.grid torch.Size([100352, 11])
# act_fun.0.coef torch.Size([100352, 13])
# act_fun.0.scale_base torch.Size([100352])
# act_fun.0.scale_sp torch.Size([100352])
# act_fun.0.mask torch.Size([100352])
# act_fun.1.grid torch.Size([8192, 11])
# act_fun.1.coef torch.Size([8192, 13])
# act_fun.1.scale_base torch.Size([8192])
# act_fun.1.scale_sp torch.Size([8192])
# act_fun.1.mask torch.Size([8192])
# act_fun.2.grid torch.Size([2048, 11])
# act_fun.2.coef torch.Size([2048, 13])
# act_fun.2.scale_base torch.Size([2048])
# act_fun.2.scale_sp torch.Size([2048])
# act_fun.2.mask torch.Size([2048])
# act_fun.3.grid torch.Size([512, 11])
# act_fun.3.coef torch.Size([512, 13])
# act_fun.3.scale_base torch.Size([512])
# act_fun.3.scale_sp torch.Size([512])
# act_fun.3.mask torch.Size([512])
# act_fun.4.grid torch.Size([32, 11])
# act_fun.4.coef torch.Size([32, 13])
# act_fun.4.scale_base torch.Size([32])
# act_fun.4.scale_sp torch.Size([32])
# act_fun.4.mask torch.Size([32])
# symbolic_fun.0.mask torch.Size([128, 784])
# symbolic_fun.0.affine torch.Size([128, 784, 4])
# symbolic_fun.1.mask torch.Size([64, 128])
# symbolic_fun.1.affine torch.Size([64, 128, 4])
# symbolic_fun.2.mask torch.Size([32, 64])
# symbolic_fun.2.affine torch.Size([32, 64, 4])
# symbolic_fun.3.mask torch.Size([16, 32])
# symbolic_fun.3.affine torch.Size([16, 32, 4])
# symbolic_fun.4.mask torch.Size([2, 16])
# symbolic_fun.4.affine torch.Size([2, 16, 4])
# 3556594

# %%
def train_acc():
    return torch.mean((torch.round(model(dataset['train_input'])) == dataset['train_label']).float())

def test_acc():
    return torch.mean((torch.round(model(dataset['test_input'])) == dataset['test_label']).float())

results = model.train(dataset, opt="LBFGS", steps=1, batch=-1, loss_fn=None, 
                      lamb=0.01, lamb_entropy=10., update_grid=False,
                      grid_update_num=10, metrics=(train_acc, test_acc));
#results['train_acc'][-1], results['test_acc'][-1]

''' dataset, opt="LBFGS", steps=100, log=1, lamb=0., lamb_l1=1., lamb_entropy=2., lamb_coef=0., 
lamb_coefdiff=0., update_grid=True, grid_update_num=10, loss_fn=None, lr=1., stop_grid_update_step=50, 
batch=-1, small_mag_threshold=1e-16, small_reg_factor=1., metrics=None, sglr_avoid=False, 
save_fig=False, in_vars=None, out_vars=None, beta=3, save_fig_freq=1, img_folder='./video', device='cpu')


steps = training_steps = epochs * num_batches = epochs * rpund_up(train_dataset.size()/num_batches)
'''
# Out:
# train loss: 5.71e-01 | test loss: 5.24e-01 | reg: 3.01e+03 : 100%|███| 1/1 [12:28<00:00, 748.48s/it]
# ' dataset, opt="LBFGS", steps=100, log=1, lamb=0., lamb_l1=1., lamb_entropy=2., lamb_coef=0., \nlamb_coefdiff=0., update_grid=True, grid_update_num=10, loss_fn=None, lr=1., stop_grid_update_step=50, \nbatch=-1, small_mag_threshold=1e-16, small_reg_factor=1., metrics=None, sglr_avoid=False, \nsave_fig=False, in_vars=None, out_vars=None, beta=3, save_fig_freq=1, img_folder=\'./video\', device=\'cpu\')\n\n\nsteps = training_steps = epochs * num_batches = epochs * rpund_up(train_dataset.size()/num_batches)\n'

# %%
results['train_acc'][-1], results['test_acc'][-1]
# Out:
# (0.5550000071525574, 0.5299999713897705)

# %%
def plot(model, folder="./figures", beta=3, mask=False, mode="supervised", scale=0.5, tick=False, sample=False, in_vars=None, out_vars=None, title=None):
    '''
    plot KAN
    
    Args:
    -----
        folder : str
            the folder to store pngs
        beta : float
            positive number. control the transparency of each activation. transparency = tanh(beta*l1).
        mask : bool
            If True, plot with mask (need to run prune() first to obtain mask). If False (by default), plot all activation functions.
        mode : bool
            "supervised" or "unsupervised". If "supervised", l1 is measured by absolution value (not subtracting mean); if "unsupervised", l1 is measured by standard deviation (subtracting mean).
        scale : float
            control the size of the diagram
        in_vars: None or list of str
            the name(s) of input variables
        out_vars: None or list of str
            the name(s) of output variables
        title: None or str
            title
        
    Returns:
    --------
        Figure
        
    Example
    -------
    >>> # see more interactive examples in demos
    >>> model = KAN(width=[2,3,1], grid=3, k=3, noise_scale=1.0)
    >>> x = torch.normal(0,1,size=(100,2))
    >>> model(x) # do a forward pass to obtain model.acts
    >>> model.plot()
    '''
    if not os.path.exists(folder):
        os.makedirs(folder)
    # matplotlib.use('Agg')
    depth = len(model.width) - 1
    for l in range(depth-1, depth):
        w_large = 2.0
        for i in range(model.width[l]):
            for j in range(model.width[l + 1]):
                rank = torch.argsort(model.acts[l][:, i])
                fig, ax = plt.subplots(figsize=(w_large, w_large))

                num = rank.shape[0]

                symbol_mask = model.symbolic_fun[l].mask[j][i]
                numerical_mask = model.act_fun[l].mask.reshape(model.width[l + 1], model.width[l])[j][i]
                if symbol_mask > 0. and numerical_mask > 0.:
                    color = 'purple'
                    alpha_mask = 1
                if symbol_mask > 0. and numerical_mask == 0.:
                    color = "red"
                    alpha_mask = 1
                if symbol_mask == 0. and numerical_mask > 0.:
                    color = "black"
                    alpha_mask = 1
                if symbol_mask == 0. and numerical_mask == 0.:
                    color = "white"
                    alpha_mask = 0

                if tick == True:
                    ax.tick_params(axis="y", direction="in", pad=-22, labelsize=50)
                    ax.tick_params(axis="x", direction="in", pad=-15, labelsize=50)
                    x_min, x_max, y_min, y_max = model.get_range(l, i, j, verbose=False)
                    plt.xticks([x_min, x_max], ['%2.f' % x_min, '%2.f' % x_max])
                    plt.yticks([y_min, y_max], ['%2.f' % y_min, '%2.f' % y_max])
                else:
                    plt.xticks([])
                    plt.yticks([])
                if alpha_mask == 1:
                    plt.gca().patch.set_edgecolor('black')
                else:
                    plt.gca().patch.set_edgecolor('white')
                plt.gca().patch.set_linewidth(1.5)
                # plt.axis('off')

                plt.plot(model.acts[l][:, i][rank].cpu().detach().numpy(), model.spline_postacts[l][:, j, i][rank].cpu().detach().numpy(), color=color, lw=5)
                if sample == True:
                    plt.scatter(model.acts[l][:, i][rank].cpu().detach().numpy(), model.spline_postacts[l][:, j, i][rank].cpu().detach().numpy(), color=color, s=400 * scale ** 2)
                plt.gca().spines[:].set_color(color)

                lock_id = model.act_fun[l].lock_id[j * model.width[l] + i].long().item()
                if lock_id > 0:
                    im = plt.imread(f'{folder}/lock.png')
                    newax = fig.add_axes([0.15, 0.7, 0.15, 0.15])
                    plt.text(500, 400, lock_id, fontsize=15)
                    newax.imshow(im)
                    newax.axis('off')

                plt.savefig(f'{folder}/sp_{l}_{i}_{j}.png', bbox_inches="tight", dpi=400)
                plt.close()

    def score2alpha(score):
        return np.tanh(beta * score)

    if mode == "supervised":
        alpha = [score2alpha(score.cpu().detach().numpy()) for score in model.acts_scale]
    elif mode == "unsupervised":
        alpha = [score2alpha(score.cpu().detach().numpy()) for score in model.acts_scale_std]

    # draw skeleton
    width = np.array(model.width)
    A = 1
    y0 = 0.4  # 0.4

    # plt.figure(figsize=(5,5*(neuron_depth-1)*y0))
    neuron_depth = len(width)
    min_spacing = A / np.maximum(np.max(width), 5)

    max_neuron = np.max(width)
    max_num_weights = np.max(width[:-1] * width[1:])
    y1 = 0.4 / np.maximum(max_num_weights, 3)

    fig, ax = plt.subplots(figsize=(10 * scale, 10 * scale * (neuron_depth - 1) * y0))
    # fig, ax = plt.subplots(figsize=(5,5*(neuron_depth-1)*y0))

    # plot scatters and lines
    for l in range(neuron_depth):
        n = width[l]
        spacing = A / n
        for i in range(n):
            plt.scatter(1 / (2 * n) + i / n, l * y0, s=min_spacing ** 2 * 10000 * scale ** 2, color='black')

            if l < neuron_depth - 1:
                # plot connections
                n_next = width[l + 1]
                N = n * n_next
                for j in range(n_next):
                    id_ = i * n_next + j

                    symbol_mask = model.symbolic_fun[l].mask[j][i]
                    numerical_mask = model.act_fun[l].mask.reshape(model.width[l + 1], model.width[l])[j][i]
                    if symbol_mask == 1. and numerical_mask == 1.:
                        color = 'purple'
                        alpha_mask = 1.
                    if symbol_mask == 1. and numerical_mask == 0.:
                        color = "red"
                        alpha_mask = 1.
                    if symbol_mask == 0. and numerical_mask == 1.:
                        color = "black"
                        alpha_mask = 1.
                    if symbol_mask == 0. and numerical_mask == 0.:
                        color = "white"
                        alpha_mask = 0.
                    if mask == True:
                        plt.plot([1 / (2 * n) + i / n, 1 / (2 * N) + id_ / N], [l * y0, (l + 1 / 2) * y0 - y1], color=color, lw=2 * scale, alpha=alpha[l][j][i] * model.mask[l][i].item() * model.mask[l + 1][j].item())
                        plt.plot([1 / (2 * N) + id_ / N, 1 / (2 * n_next) + j / n_next], [(l + 1 / 2) * y0 + y1, (l + 1) * y0], color=color, lw=2 * scale, alpha=alpha[l][j][i] * model.mask[l][i].item() * model.mask[l + 1][j].item())
                    else:
                        plt.plot([1 / (2 * n) + i / n, 1 / (2 * N) + id_ / N], [l * y0, (l + 1 / 2) * y0 - y1], color=color, lw=2 * scale, alpha=alpha[l][j][i] * alpha_mask)
                        plt.plot([1 / (2 * N) + id_ / N, 1 / (2 * n_next) + j / n_next], [(l + 1 / 2) * y0 + y1, (l + 1) * y0], color=color, lw=2 * scale, alpha=alpha[l][j][i] * alpha_mask)

        plt.xlim(0, 1)
        plt.ylim(-0.1 * y0, (neuron_depth - 1 + 0.1) * y0)

    # -- Transformation functions
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    # -- Take data coordinates and transform them to normalized figure coordinates
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))

    plt.axis('off')

    # plot splines
    for l in range(neuron_depth - 1):
        n = width[l]
        for i in range(n):
            n_next = width[l + 1]
            N = n * n_next
            for j in range(n_next):
                id_ = i * n_next + j
                im = plt.imread(f'{folder}/sp_{l}_{i}_{j}.png')
                left = DC_to_NFC([1 / (2 * N) + id_ / N - y1, 0])[0]
                right = DC_to_NFC([1 / (2 * N) + id_ / N + y1, 0])[0]
                bottom = DC_to_NFC([0, (l + 1 / 2) * y0 - y1])[1]
                up = DC_to_NFC([0, (l + 1 / 2) * y0 + y1])[1]
                newax = fig.add_axes([left, bottom, right - left, up - bottom])
                # newax = fig.add_axes([1/(2*N)+id_/N-y1, (l+1/2)*y0-y1, y1, y1], anchor='NE')
                if mask == False:
                    newax.imshow(im, alpha=alpha[l][j][i])
                else:
                    ### make sure to run model.prune() first to compute mask ###
                    newax.imshow(im, alpha=alpha[l][j][i] * model.mask[l][i].item() * model.mask[l + 1][j].item())
                newax.axis('off')

    if in_vars != None:
        n = model.width[0]
        for i in range(n):
            plt.gcf().get_axes()[0].text(1 / (2 * (n)) + i / (n), -0.1, in_vars[i], fontsize=40 * scale, horizontalalignment='center', verticalalignment='center')

    if out_vars != None:
        n = model.width[-1]
        for i in range(n):
            plt.gcf().get_axes()[0].text(1 / (2 * (n)) + i / (n), y0 * (len(model.width) - 1) + 0.1, out_vars[i], fontsize=40 * scale, horizontalalignment='center', verticalalignment='center')

    if title != None:
        plt.gcf().get_axes()[0].text(0.5, y0 * (len(model.width) - 1) + 0.2, title, fontsize=40 * scale, horizontalalignment='center', verticalalignment='center')

# %%
#model(dataset["train_input"][:10])
# the last layer plottings work. This is because, as the data is so large, as well as the model,
# I was probably not training enough, and what happens is that the first layers produce the same (x,y) per i,j
# for every image in the training dataser (plot=1 point)
# x = pre-spline activations/input of each layer (batch, in_dim); y= post_spline activations (batch, in_dim, out_dim)
#model.plot()
plot(model)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[43], line 5
#       1 #model(dataset["train_input"][:10])
#       2 # TRY TO PLOT ONLY FOR LAST LAYER
#       3 # is the scale of the plot too large? Or is the plot empty because every sample/img has the same (x,y) value? plot=1point
#       4 #model.plot()
# ----> 5 plot(model)
#
# Cell In[42], line 174, in plot(model, folder, beta, mask, mode, scale, tick, sample, in_vars, out_vars, title)
#     172 for j in range(n_next):
#     173     id_ = i * n_next + j
# --> 174     im = plt.imread(f'{folder}/sp_{l}_{i}_{j}.png')
#     175     left = DC_to_NFC([1 / (2 * N) + id_ / N - y1, 0])[0]
#     176     right = DC_to_NFC([1 / (2 * N) + id_ / N + y1, 0])[0]
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/pyplot.py:2123, in imread(fname, format)
#    2121 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2122 def imread(fname, format=None):
# -> 2123     return matplotlib.image.imread(fname, format)
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/image.py:1541, in imread(fname, format)
#    1534 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1535     # Pillow doesn't handle URLs directly.
#    1536     raise ValueError(
#    1537         "Please open the URL for reading and pass the "
#    1538         "result to Pillow, e.g. with "
#    1539         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1540         )
# -> 1541 with img_open(fname) as image:
#    1542     return (_pil_png_to_float_array(image)
#    1543             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1544             pil_to_array(image))
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/PIL/ImageFile.py:125, in ImageFile.__init__(self, fp, filename)
#     121 self.decodermaxblock = MAXBLOCK
#     123 if is_path(fp):
#     124     # filename
# --> 125     self.fp = open(fp, "rb")
#     126     self.filename = fp
#     127     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: './figures/sp_0_0_0.png'
# Error in callback <function flush_figures at 0x7f8af8e8bb00> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/IPython/core/formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/backend_bases.py:2314, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2308     renderer = _get_renderer(
#    2309         self.figure,
#    2310         functools.partial(
#    2311             print_method, orientation=orientation)
#    2312     )
#    2313     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2314         self.figure.draw(renderer)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/figure.py:3071, in Figure.draw(self, renderer)
#    3068         # ValueError can occur when resizing a window.
#    3070 self.patch.draw(renderer)
# -> 3071 mimage._draw_list_compositing_images(
#    3072     renderer, self, artists, self.suppressComposite)
#    3074 for sfig in self.subfigs:
#    3075     sfig.draw(renderer)
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/axes/_base.py:3107, in _AxesBase.draw(self, renderer)
#    3104         a.draw(renderer)
#    3105     renderer.stop_rasterizing()
# -> 3107 mimage._draw_list_compositing_images(
#    3108     renderer, self, artists, self.figure.suppressComposite)
#    3110 renderer.close_group('axes')
#    3111 self.stale = False
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/collections.py:976, in _CollectionWithSizes.draw(self, renderer)
#     973 @artist.allow_rasterization
#     974 def draw(self, renderer):
#     975     self.set_sizes(self._sizes, self.figure.dpi)
# --> 976     super().draw(renderer)
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/collections.py:389, in Collection.draw(self, renderer)
#     387 else:
#     388     combined_transform = transform
# --> 389 extents = paths[0].get_extents(combined_transform)
#     390 if (extents.width < self.figure.bbox.width
#     391         and extents.height < self.figure.bbox.height):
#     392     do_single_path_optimization = True
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/path.py:636, in Path.get_extents(self, transform, **kwargs)
#     633 xys = []
#     634 for curve, code in self.iter_bezier(**kwargs):
#     635     # places where the derivative is zero can be extrema
# --> 636     _, dzeros = curve.axis_aligned_extrema()
#     637     # as can the ends of the curve
#     638     xys.append(curve([0, *dzeros, 1]))
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/bezier.py:294, in BezierSegment.axis_aligned_extrema(self)
#     292 if n <= 1:
#     293     return np.array([]), np.array([])
# --> 294 Cj = self.polynomial_coefficients
#     295 dCj = np.arange(1, n+1)[:, None] * Cj[1:]
#     296 dims = []
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/matplotlib/bezier.py:272, in BezierSegment.polynomial_coefficients(self)
#     270 j = np.arange(n+1)[:, None]
#     271 i = np.arange(n+1)[None, :]  # _comb is non-zero for i <= j
# --> 272 prefactor = (-1)**(i + j) * _comb(j, i)  # j on axis 0, i on axis 1
#     273 return _comb(n, j) * prefactor @ P
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/numpy/lib/function_base.py:2329, in vectorize.__call__(self, *args, **kwargs)
#    2326     vargs = [args[_i] for _i in inds]
#    2327     vargs.extend([kwargs[_n] for _n in names])
# -> 2329 return self._vectorize_call(func=func, args=vargs)
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/numpy/lib/function_base.py:2407, in vectorize._vectorize_call(self, func, args)
#    2405     res = func()
#    2406 else:
# -> 2407     ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2409     # Convert args to object arrays first
#    2410     inputs = [asanyarray(a, dtype=object) for a in args]
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/numpy/lib/function_base.py:2396, in vectorize._get_ufunc_and_otypes(self, func, args)
#    2390     otypes = ''.join([asarray(outputs[_k]).dtype.char
#    2391                       for _k in range(nout)])
#    2393     # Performance note: profiling indicates that creating the ufunc is
#    2394     # not a significant cost compared with wrapping so it seems not
#    2395     # worth trying to cache this.
# -> 2396     ufunc = frompyfunc(_func, len(args), nout)
#    2398 return ufunc, otypes
#
# KeyboardInterrupt:

# %%
l=0
for i in range(784):
    for j in range(2):
        symbol_mask = model.symbolic_fun[l].mask[j][i]
        numerical_mask = model.act_fun[l].mask.reshape(model.width[l + 1], model.width[l])[j][i]
        if symbol_mask != 0:
            print(symbol_mask)
        if numerical_mask != 1:
            print(numerical_mask)

# %%
l=4
i=0
j=0
rank = torch.argsort(model.acts[l][:, i])
model.acts[l][:, i][rank] #x in plot sp_l_i_j; each value of x corresponds to the input (dim=i) values for layer l
# Out:
# tensor([0.9566, 1.0561, 1.5314, 1.7213, 1.9203, 2.0120, 2.8071, 2.8179, 2.8220,
#         2.9448, 2.9932, 3.0043, 3.0427, 3.0429, 3.1859, 3.1922, 3.2206, 3.2578,
#         3.2589, 3.2703, 3.3166, 3.3275, 3.3315, 3.3497, 3.3661, 3.4060, 3.4147,
#         3.4387, 3.4419, 3.4491, 3.4658, 3.4699, 3.4712, 3.4725, 3.4814, 3.4859,
#         3.4882, 3.4925, 3.4931, 3.4984, 3.4996, 3.5166, 3.5174, 3.5204, 3.5266,
#         3.5276, 3.5372, 3.5391, 3.5476, 3.5545, 3.5588, 3.5639, 3.5644, 3.5659,
#         3.5669, 3.5683, 3.5727, 3.5736, 3.5746, 3.5755, 3.5770, 3.5772, 3.5772,
#         3.5774, 3.5793, 3.5793, 3.5793, 3.5797, 3.5802, 3.5802, 3.5807, 3.5807,
#         3.5808, 3.5808, 3.5809, 3.5810, 3.5810, 3.5811, 3.5811, 3.5812, 3.5812,
#         3.5812, 3.5813, 3.5814, 3.5814, 3.5814, 3.5816, 3.5822, 3.5825, 3.5832,
#         3.5832, 3.5833, 3.5849, 3.5853, 3.5855, 3.5859, 3.5866, 3.5868, 3.5871,
#         3.5931], grad_fn=<IndexBackward0>)

# %%
model.spline_postacts[l][:, j, i][rank] #y; each value of y corresponds to a batch image/sample's
#pos_spline values (batch, in_neurons, out_neurons) of layer l
# Out:
# tensor([0.3086, 0.3708, 0.3075, 0.3551, 0.4073, 0.4316, 0.6438, 0.6467, 0.6478,
#         0.6804, 0.6932, 0.6961, 0.7063, 0.7063, 0.7440, 0.7457, 0.7532, 0.7629,
#         0.7632, 0.7662, 0.7784, 0.7812, 0.7823, 0.7870, 0.7913, 0.8017, 0.8040,
#         0.8103, 0.8111, 0.8130, 0.8173, 0.8184, 0.8187, 0.8191, 0.8214, 0.8226,
#         0.8232, 0.8243, 0.8244, 0.8258, 0.8261, 0.8306, 0.8308, 0.8316, 0.8332,
#         0.8334, 0.8359, 0.8364, 0.8386, 0.8404, 0.8415, 0.8428, 0.8430, 0.8434,
#         0.8436, 0.8440, 0.8451, 0.8454, 0.8456, 0.8459, 0.8462, 0.8463, 0.8463,
#         0.8464, 0.8468, 0.8468, 0.8469, 0.8469, 0.8471, 0.8471, 0.8472, 0.8472,
#         0.8472, 0.8472, 0.8473, 0.8473, 0.8473, 0.8473, 0.8473, 0.8473, 0.8473,
#         0.8473, 0.8474, 0.8474, 0.8474, 0.8474, 0.8474, 0.8476, 0.8477, 0.8479,
#         0.8479, 0.8479, 0.8483, 0.8484, 0.8485, 0.8486, 0.8488, 0.8488, 0.8489,
#         0.8504])

# %%
l, i, j = 0, 0, 0
len(model.acts[l][:, :]), model.acts[l][0, :].shape, model.acts[l][0, :]
#model.spline_postacts[l][:, j, i]
# Out:
# (100,
#  torch.Size([784]),
#  tensor([-0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#           0.0595,  2.8088,  0.9632, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242,  0.6831,  2.7833,  0.6195, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#           1.2941,  2.6433, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242,  0.1486,  2.6815,  1.4850, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,  0.6450,
#           2.8088,  0.3777, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242,  2.1469,  2.4142, -0.2842, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.0169,  2.8088,
#           2.3251, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242,  0.7850,  2.8088,  2.0578, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,  1.3577,  2.8088,
#           0.5559, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242,  0.3013,  2.5924,  2.1851, -0.3224, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,  1.1541,  2.8215,  1.6759,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242,  1.7523,  2.8088,  0.6068, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.1187,  2.5287,  2.3124, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#           1.1032,  2.8088,  1.5996, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242,  1.4978,  2.8088,  1.3832, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#           2.4778,  2.8088,  0.4159, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242,  0.3522,  2.7706,  2.8088,  0.4159, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,  1.3705,
#           2.8088,  2.1851, -0.3860, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.2969,  2.3124,  2.8088,  1.1159, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.3606,  2.0960,
#           1.8160, -0.2969, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242,
#          -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242, -0.4242]))

# %%
lib = ['x','x^2','x^3','x^4','exp','log','sqrt','tanh','sin','tan','abs']
model.auto_symbolic(lib=lib)
formula = model.symbolic_formula()[0][0]
formula
# Out:
# fixing (0,0,0) with abs, r2=0.0
# fixing (0,0,1) with abs, r2=0.0
# fixing (0,1,0) with abs, r2=0.0
# fixing (0,1,1) with abs, r2=0.0
# fixing (0,2,0) with abs, r2=0.0
# fixing (0,2,1) with abs, r2=0.0
# fixing (0,3,0) with abs, r2=0.0
# fixing (0,3,1) with abs, r2=0.0
# fixing (0,4,0) with abs, r2=0.0
# fixing (0,4,1) with abs, r2=0.0
# fixing (0,5,0) with exp, r2=6.860967089600267e-12
# fixing (0,5,1) with abs, r2=0.0
# fixing (0,6,0) with abs, r2=0.0
# fixing (0,6,1) with abs, r2=0.0
# fixing (0,7,0) with abs, r2=0.0
# fixing (0,7,1) with abs, r2=0.0
# fixing (0,8,0) with abs, r2=0.0
# fixing (0,8,1) with abs, r2=0.0
# fixing (0,9,0) with abs, r2=0.0
# fixing (0,9,1) with abs, r2=0.0
# fixing (0,10,0) with abs, r2=0.0
# fixing (0,10,1) with abs, r2=0.0
# fixing (0,11,0) with abs, r2=0.0
# fixing (0,11,1) with abs, r2=0.0
# fixing (0,12,0) with abs, r2=0.0
# fixing (0,12,1) with abs, r2=0.0
# fixing (0,13,0) with abs, r2=0.0
# fixing (0,13,1) with abs, r2=0.0
# fixing (0,14,0) with abs, r2=0.0
# fixing (0,14,1) with abs, r2=0.0
# fixing (0,15,0) with abs, r2=0.0
# fixing (0,15,1) with abs, r2=0.0
# fixing (0,16,0) with abs, r2=0.0
# fixing (0,16,1) with abs, r2=0.0
# fixing (0,17,0) with abs, r2=0.0
# fixing (0,17,1) with abs, r2=0.0
# fixing (0,18,0) with abs, r2=0.0
# fixing (0,18,1) with abs, r2=0.0
# fixing (0,19,0) with abs, r2=0.0
# fixing (0,19,1) with abs, r2=0.0
# fixing (0,20,0) with abs, r2=0.0
# fixing (0,20,1) with abs, r2=0.0
# fixing (0,21,0) with abs, r2=0.0
# fixing (0,21,1) with abs, r2=0.0
# fixing (0,22,0) with abs, r2=0.0
# fixing (0,22,1) with abs, r2=0.0
# fixing (0,23,0) with abs, r2=0.0
# fixing (0,23,1) with abs, r2=0.0
# fixing (0,24,0) with abs, r2=0.0
# fixing (0,24,1) with abs, r2=0.0
# fixing (0,25,0) with abs, r2=0.0
# fixing (0,25,1) with abs, r2=0.0
# fixing (0,26,0) with abs, r2=0.0
# fixing (0,26,1) with abs, r2=0.0
# fixing (0,27,0) with abs, r2=0.0
# fixing (0,27,1) with abs, r2=0.0
# fixing (0,28,0) with abs, r2=0.0
# fixing (0,28,1) with abs, r2=0.0
# fixing (0,29,0) with abs, r2=0.0
# fixing (0,29,1) with abs, r2=0.0
# fixing (0,30,0) with abs, r2=0.0
# fixing (0,30,1) with exp, r2=1.0977547343360428e-10
# fixing (0,31,0) with abs, r2=0.0
# fixing (0,31,1) with abs, r2=0.0
# fixing (0,32,0) with abs, r2=0.0
# fixing (0,32,1) with abs, r2=0.0
# fixing (0,33,0) with abs, r2=0.0
# fixing (0,33,1) with abs, r2=0.0
# fixing (0,34,0) with abs, r2=0.0
# fixing (0,34,1) with abs, r2=0.0
# fixing (0,35,0) with abs, r2=0.0
# fixing (0,35,1) with abs, r2=0.0
# fixing (0,36,0) with abs, r2=0.0
# fixing (0,36,1) with abs, r2=0.0
# fixing (0,37,0) with abs, r2=0.0
# fixing (0,37,1) with abs, r2=0.0
# fixing (0,38,0) with abs, r2=0.0
# fixing (0,38,1) with abs, r2=0.0
# fixing (0,39,0) with abs, r2=0.0
# fixing (0,39,1) with abs, r2=0.0
# fixing (0,40,0) with abs, r2=0.0
# fixing (0,40,1) with abs, r2=0.0
# fixing (0,41,0) with abs, r2=0.0
# fixing (0,41,1) with abs, r2=0.0
# fixing (0,42,0) with abs, r2=0.0
# fixing (0,42,1) with abs, r2=0.0
# fixing (0,43,0) with abs, r2=0.0
# fixing (0,43,1) with abs, r2=0.0
# fixing (0,44,0) with abs, r2=0.0
# fixing (0,44,1) with abs, r2=0.0
# fixing (0,45,0) with exp, r2=1.951563910473908e-10
# fixing (0,45,1) with abs, r2=0.0
# fixing (0,46,0) with abs, r2=0.0
# fixing (0,46,1) with abs, r2=0.0
# fixing (0,47,0) with abs, r2=0.0
# fixing (0,47,1) with abs, r2=0.0
# fixing (0,48,0) with abs, r2=0.0
# fixing (0,48,1) with abs, r2=0.0
# fixing (0,49,0) with abs, r2=0.0
# fixing (0,49,1) with abs, r2=0.0
# fixing (0,50,0) with abs, r2=0.0
# fixing (0,50,1) with abs, r2=0.0
# fixing (0,51,0) with abs, r2=0.0
# fixing (0,51,1) with abs, r2=0.0
# fixing (0,52,0) with abs, r2=0.0
# fixing (0,52,1) with abs, r2=0.0
# fixing (0,53,0) with abs, r2=0.0
# fixing (0,53,1) with abs, r2=0.0
# fixing (0,54,0) with abs, r2=0.0
# fixing (0,54,1) with abs, r2=0.0
# fixing (0,55,0) with abs, r2=0.0
# fixing (0,55,1) with abs, r2=0.0
# fixing (0,56,0) with abs, r2=0.0
# fixing (0,56,1) with abs, r2=0.0
# fixing (0,57,0) with abs, r2=0.0
# fixing (0,57,1) with abs, r2=0.0
# fixing (0,58,0) with abs, r2=0.0
# fixing (0,58,1) with abs, r2=0.0
# fixing (0,59,0) with exp, r2=7.025630299750674e-09
# fixing (0,59,1) with abs, r2=0.0
# fixing (0,60,0) with abs, r2=0.0
# fixing (0,60,1) with abs, r2=0.0
# fixing (0,61,0) with abs, r2=0.0
# fixing (0,61,1) with abs, r2=0.0
# fixing (0,62,0) with abs, r2=0.0
# fixing (0,62,1) with abs, r2=0.0
# fixing (0,63,0) with abs, r2=0.0
# fixing (0,63,1) with abs, r2=0.0
# fixing (0,64,0) with abs, r2=0.0
# fixing (0,64,1) with abs, r2=0.0
# fixing (0,65,0) with abs, r2=0.0
# fixing (0,65,1) with abs, r2=0.0
# fixing (0,66,0) with abs, r2=0.0
# fixing (0,66,1) with abs, r2=0.0
# fixing (0,67,0) with abs, r2=0.0
# fixing (0,67,1) with abs, r2=0.0
# fixing (0,68,0) with abs, r2=0.0
# fixing (0,68,1) with abs, r2=0.0
# fixing (0,69,0) with exp, r2=1.951563910473908e-10
# fixing (0,69,1) with abs, r2=0.0
# fixing (0,70,0) with abs, r2=0.0
# fixing (0,70,1) with abs, r2=0.0
# fixing (0,71,0) with abs, r2=0.0
# fixing (0,71,1) with abs, r2=0.0
# fixing (0,72,0) with exp, r2=1.0977547343360428e-10
# fixing (0,72,1) with abs, r2=0.0
# fixing (0,73,0) with abs, r2=0.0
# fixing (0,73,1) with abs, r2=0.0
# fixing (0,74,0) with abs, r2=0.0
# fixing (0,74,1) with abs, r2=0.0
# fixing (0,75,0) with abs, r2=0.0
# fixing (0,75,1) with abs, r2=0.0
# fixing (0,76,0) with abs, r2=0.0
# fixing (0,76,1) with abs, r2=0.0
# fixing (0,77,0) with abs, r2=0.0
# fixing (0,77,1) with abs, r2=0.0
# fixing (0,78,0) with abs, r2=0.0
# fixing (0,78,1) with abs, r2=0.0
# fixing (0,79,0) with abs, r2=0.0
# fixing (0,79,1) with abs, r2=0.0
# fixing (0,80,0) with abs, r2=0.0
# fixing (0,80,1) with abs, r2=0.0
# fixing (0,81,0) with abs, r2=0.0
# fixing (0,81,1) with abs, r2=0.0
# fixing (0,82,0) with abs, r2=0.0
# fixing (0,82,1) with abs, r2=0.0
# fixing (0,83,0) with abs, r2=0.0
# fixing (0,83,1) with abs, r2=0.0
# fixing (0,84,0) with abs, r2=0.0
# fixing (0,84,1) with abs, r2=0.0
# fixing (0,85,0) with abs, r2=0.0
# fixing (0,85,1) with abs, r2=0.0
# fixing (0,86,0) with abs, r2=0.0
# fixing (0,86,1) with abs, r2=0.0
# fixing (0,87,0) with abs, r2=0.0
# fixing (0,87,1) with abs, r2=0.0
# fixing (0,88,0) with abs, r2=0.0
# fixing (0,88,1) with abs, r2=0.0
# fixing (0,89,0) with abs, r2=0.0
# fixing (0,89,1) with abs, r2=0.0
# fixing (0,90,0) with abs, r2=0.0
# fixing (0,90,1) with abs, r2=0.0
# fixing (0,91,0) with abs, r2=0.0
# fixing (0,91,1) with abs, r2=0.0
# fixing (0,92,0) with abs, r2=0.0
# fixing (0,92,1) with abs, r2=0.0
# fixing (0,93,0) with abs, r2=0.0
# fixing (0,93,1) with abs, r2=0.0
# fixing (0,94,0) with abs, r2=0.0
# fixing (0,94,1) with abs, r2=0.0
# fixing (0,95,0) with abs, r2=0.0
# fixing (0,95,1) with abs, r2=0.0
# fixing (0,96,0) with abs, r2=0.0
# fixing (0,96,1) with abs, r2=0.0
# fixing (0,97,0) with x^4, r2=1.0000025033950806
# fixing (0,97,1) with tan, r2=1.0000020265579224
# fixing (0,98,0) with x^3, r2=1.0000028610229492
# fixing (0,98,1) with x^3, r2=1.0000032186508179
# fixing (0,99,0) with exp, r2=1.0000030994415283
# fixing (0,99,1) with exp, r2=1.0000030994415283
# fixing (0,100,0) with abs, r2=0.0
# fixing (0,100,1) with abs, r2=0.0
# fixing (0,101,0) with exp, r2=7.806255641895632e-10
# fixing (0,101,1) with exp, r2=4.87890977618477e-11
# fixing (0,102,0) with exp, r2=1.000002145767212
# fixing (0,102,1) with exp, r2=1.0000019073486328
# fixing (0,103,0) with exp, r2=1.0000015497207642
# fixing (0,103,1) with exp, r2=1.0000022649765015
# fixing (0,104,0) with exp, r2=1.000002145767212
# fixing (0,104,1) with x^3, r2=1.0000019073486328
# fixing (0,105,0) with exp, r2=1.000002145767212
# fixing (0,105,1) with x^4, r2=1.0000022649765015
# fixing (0,106,0) with abs, r2=0.0
# fixing (0,106,1) with abs, r2=0.0
# fixing (0,107,0) with abs, r2=0.0
# fixing (0,107,1) with abs, r2=0.0
# fixing (0,108,0) with abs, r2=0.0
# fixing (0,108,1) with abs, r2=0.0
# fixing (0,109,0) with abs, r2=0.0
# fixing (0,109,1) with abs, r2=0.0
# fixing (0,110,0) with abs, r2=0.0
# fixing (0,110,1) with exp, r2=1.951563910473908e-10
# fixing (0,111,0) with abs, r2=0.0
# fixing (0,111,1) with abs, r2=0.0
# fixing (0,112,0) with abs, r2=0.0
# fixing (0,112,1) with abs, r2=0.0
# fixing (0,113,0) with abs, r2=0.0
# fixing (0,113,1) with abs, r2=0.0
# fixing (0,114,0) with abs, r2=0.0
# fixing (0,114,1) with abs, r2=0.0
# fixing (0,115,0) with abs, r2=0.0
# fixing (0,115,1) with abs, r2=0.0
# fixing (0,116,0) with abs, r2=0.0
# fixing (0,116,1) with abs, r2=0.0
# fixing (0,117,0) with exp, r2=2.9778502051908996e-15
# fixing (0,117,1) with abs, r2=0.0
# fixing (0,118,0) with abs, r2=0.0
# fixing (0,118,1) with abs, r2=0.0
# fixing (0,119,0) with exp, r2=3.0493186101154812e-12
# fixing (0,119,1) with exp, r2=7.806255641895632e-10
# fixing (0,120,0) with exp, r2=1.0000016689300537
# fixing (0,120,1) with x^3, r2=1.0000020265579224
# fixing (0,121,0) with exp, r2=1.0000019073486328
# fixing (0,121,1) with x^3, r2=1.0000020265579224
# fixing (0,122,0) with abs, r2=0.9999983906745911
# fixing (0,122,1) with abs, r2=0.9999976754188538
# fixing (0,123,0) with abs, r2=0.9999485611915588
# fixing (0,123,1) with sin, r2=0.9999638795852661
# fixing (0,124,0) with tan, r2=0.9909769296646118
# fixing (0,124,1) with sin, r2=0.9992327690124512
# fixing (0,125,0) with tanh, r2=0.9995858073234558
# fixing (0,125,1) with tanh, r2=0.9999901652336121
# fixing (0,126,0) with tanh, r2=0.9994800686836243
# fixing (0,126,1) with sin, r2=0.9999744296073914
# fixing (0,127,0) with tanh, r2=0.999923586845398
# fixing (0,127,1) with sin, r2=0.9992491006851196
# fixing (0,128,0) with tanh, r2=0.9998056888580322
# fixing (0,128,1) with sin, r2=0.9973900318145752
# fixing (0,129,0) with sin, r2=0.9972172975540161
# fixing (0,129,1) with x^2, r2=0.941767156124115
# fixing (0,130,0) with sin, r2=0.9999366998672485
# fixing (0,130,1) with tanh, r2=0.9998175501823425
# fixing (0,131,0) with tan, r2=0.9994527697563171
# fixing (0,131,1) with exp, r2=0.9997899532318115
# fixing (0,132,0) with sin, r2=0.9949353933334351
# fixing (0,132,1) with exp, r2=0.9999476671218872
# fixing (0,133,0) with exp, r2=1.0000028610229492
# fixing (0,133,1) with x^4, r2=1.0000025033950806
# fixing (0,134,0) with exp, r2=3.1225022567582528e-09
# fixing (0,134,1) with exp, r2=1.951563910473908e-10
# fixing (0,135,0) with exp, r2=3.0493186101154812e-12
# fixing (0,135,1) with abs, r2=0.0
# fixing (0,136,0) with abs, r2=0.0
# fixing (0,136,1) with abs, r2=0.0
# fixing (0,137,0) with abs, r2=0.0
# fixing (0,137,1) with abs, r2=0.0
# fixing (0,138,0) with abs, r2=0.0
# fixing (0,138,1) with abs, r2=0.0
# fixing (0,139,0) with abs, r2=0.0
# fixing (0,139,1) with abs, r2=0.0
# fixing (0,140,0) with abs, r2=0.0
# fixing (0,140,1) with abs, r2=0.0
# fixing (0,141,0) with abs, r2=0.0
# fixing (0,141,1) with abs, r2=0.0
# fixing (0,142,0) with abs, r2=0.0
# fixing (0,142,1) with abs, r2=0.0
# fixing (0,143,0) with abs, r2=0.0
# fixing (0,143,1) with abs, r2=0.0
# fixing (0,144,0) with abs, r2=0.0
# fixing (0,144,1) with abs, r2=0.0
# fixing (0,145,0) with abs, r2=0.0
# fixing (0,145,1) with abs, r2=0.0
# fixing (0,146,0) with abs, r2=0.0
# fixing (0,146,1) with exp, r2=1.7564075749376684e-09
# fixing (0,147,0) with abs, r2=0.0
# fixing (0,147,1) with abs, r2=0.0
# fixing (0,148,0) with exp, r2=1.0000019073486328
# fixing (0,148,1) with x^3, r2=1.0000019073486328
# fixing (0,149,0) with tan, r2=0.9999839663505554
# fixing (0,149,1) with x^2, r2=0.9999977946281433
# fixing (0,150,0) with sin, r2=0.9996206164360046
# fixing (0,150,1) with sin, r2=0.9999118447303772
# fixing (0,151,0) with tanh, r2=0.9990068078041077
# fixing (0,151,1) with sin, r2=0.9999868273735046
# fixing (0,152,0) with tanh, r2=0.9997444748878479
# fixing (0,152,1) with sin, r2=0.9999452233314514
# fixing (0,153,0) with tanh, r2=0.9999593496322632
# fixing (0,153,1) with tan, r2=0.9834844470024109
# fixing (0,154,0) with sin, r2=0.9999876022338867
# fixing (0,154,1) with sin, r2=0.999967098236084
# fixing (0,155,0) with sin, r2=0.9890943169593811
# fixing (0,155,1) with log, r2=0.9996317028999329
# fixing (0,156,0) with sin, r2=0.9995900392532349
# fixing (0,156,1) with tan, r2=0.9986904859542847
# fixing (0,157,0) with tanh, r2=0.9999871850013733
# fixing (0,157,1) with sin, r2=0.9999290108680725
# fixing (0,158,0) with sin, r2=0.992456316947937
# fixing (0,158,1) with sin, r2=0.9999920725822449
# fixing (0,159,0) with sin, r2=0.9963570237159729
# fixing (0,159,1) with sin, r2=0.9999563694000244
# fixing (0,160,0) with tan, r2=1.0
# fixing (0,160,1) with x^2, r2=0.9999917149543762
# fixing (0,161,0) with x^4, r2=1.000002145767212
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 lib = ['x','x^2','x^3','x^4','exp','log','sqrt','tanh','sin','tan','abs']
# ----> 2 model.auto_symbolic(lib=lib)
#       3 formula = model.symbolic_formula()[0][0]
#       4 formula
#
# File ~/Anansi/MA/KG/KAN/pykan/kan/KAN.py:1168, in KAN.auto_symbolic(self, a_range, b_range, lib, verbose)
#    1166     print(f'skipping ({l},{i},{j}) since already symbolic')
#    1167 else:
# -> 1168     name, fun, r2 = self.suggest_symbolic(l, i, j, a_range=a_range, b_range=b_range, lib=lib, verbose=False)
#    1169     self.fix_symbolic(l, i, j, name, verbose=verbose > 1)
#    1170     if verbose >= 1:
#
# File ~/Anansi/MA/KG/KAN/pykan/kan/KAN.py:1099, in KAN.suggest_symbolic(self, l, i, j, a_range, b_range, lib, topk, verbose)
#    1096         symbolic_lib[item] = SYMBOLIC_LIB[item]
#    1098 for (name, fun) in symbolic_lib.items():
# -> 1099     r2 = self.fix_symbolic(l, i, j, name, a_range=a_range, b_range=b_range, verbose=False)
#    1100     r2s.append(r2.item())
#    1102 self.unfix_symbolic(l, i, j)
#
# File ~/Anansi/MA/KG/KAN/pykan/kan/KAN.py:453, in KAN.fix_symbolic(self, l, i, j, fun_name, fit_params_bool, a_range, b_range, verbose, random)
#     451 x = self.acts[l][:, i]
#     452 y = self.spline_postacts[l][:, j, i]
# --> 453 r2 = self.symbolic_fun[l].fix_symbolic(i, j, fun_name, x, y, a_range=a_range, b_range=b_range, verbose=verbose)
#     454 return r2
#
# File ~/Anansi/MA/KG/KAN/pykan/kan/Symbolic_KANLayer.py:222, in Symbolic_KANLayer.fix_symbolic(self, i, j, fun_name, x, y, random, a_range, b_range, verbose)
#     219     return None
#     220 else:
#     221     #initialize from x & y and fun
# --> 222     params, r2 = fit_params(x,y,fun, a_range=a_range, b_range=b_range, verbose=verbose, device=self.device)
#     223     self.funs[j][i] = fun
#     224     self.affine.data[j][i] = params
#
# File ~/Anansi/MA/KG/KAN/pykan/kan/utils.py:190, in fit_params(x, y, fun, a_range, b_range, grid_number, iteration, verbose, device)
#     188 y_mean = torch.mean(y, dim=[0], keepdim=True)
#     189 numerator = torch.sum((post_fun - x_mean)*(y-y_mean)[:,None,None], dim=0)**2
# --> 190 denominator = torch.sum((post_fun - x_mean)**2, dim=0)*torch.sum((y - y_mean)[:,None,None]**2, dim=0)
#     191 r2 = numerator/(denominator+1e-4)
#     192 r2 = torch.nan_to_num(r2)
#
# File ~/miniconda3/envs/pykan-env/lib/python3.11/site-packages/torch/_tensor.py:34, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      31 def _handle_torch_function_and_wrap_type_error_to_not_implemented(f):
#      32     assigned = functools.WRAPPER_ASSIGNMENTS
# ---> 34     @functools.wraps(f, assigned=assigned)
#      35     def wrapped(*args, **kwargs):
#      36         try:
#      37             # See https://github.com/pytorch/pytorch/issues/75462
#      38             if has_torch_function(args):
#
# KeyboardInterrupt:

# %%
del model

# %% [markdown]
# How do they increase number of grid points during training?
# *   at each n step, they just reinitialize the model with this method: initialize_from_another_model?
